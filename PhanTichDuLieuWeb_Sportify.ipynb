# %%
pip install spotipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: idna<3,>=2.5 in c:\users\tuyen\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (2.10)
# ...

# %%
import requests
client_id='2a369d4afd1e4eccafe667acb8f35307'
client_secret='c173230e09574c92953e418b8a48d75c'

# %%
AUTH_URL = 'https://accounts.spotify.com/api/token'

# POST
auth_response = requests.post(AUTH_URL, {
    'grant_type': 'client_credentials',
    'client_id': client_id,
    'client_secret': client_secret,
})
# convert the response to JSON
auth_response_data = auth_response.json()

# save the access token
access_token = auth_response_data['access_token']

# %%
headers = {
    'Authorization': 'Bearer {token}'.format(token=access_token)
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e7aa0bcbc517> in <module>
#       1 headers = {
# ----> 2     'Authorization': 'Bearer {token}'.format(token=access_token)
#       3 }
#
# NameError: name 'access_token' is not defined

# %%
# base URL of all Spotify API endpoints
BASE_URL = 'https://api.spotify.com/v1/'

# Track ID from the URI
track_id = '6y0igZArWVi6Iz0rj35c1Y'

# actual GET request with proper header
r = requests.get(BASE_URL + 'audio-features/' + track_id, headers=headers)

# %%
r = r.json()
r
# Out:
# {'danceability': 0.54,
#  'energy': 0.59,
#  'key': 0,
#  'loudness': -4.359,
#  'mode': 1,
#  'speechiness': 0.0528,
#  'acousticness': 0.446,
#  'instrumentalness': 0,
#  'liveness': 0.14,
#  'valence': 0.267,
#  'tempo': 119.878,
#  'type': 'audio_features',
#  'id': '6y0igZArWVi6Iz0rj35c1Y',
#  'uri': 'spotify:track:6y0igZArWVi6Iz0rj35c1Y',
#  'track_href': 'https://api.spotify.com/v1/tracks/6y0igZArWVi6Iz0rj35c1Y',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6y0igZArWVi6Iz0rj35c1Y',
#  'duration_ms': 234910,
#  'time_signature': 4}

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

birdy_uri = 'spotify:artist:2WX2uTcsvV5OnS0inACecP'
spotify = spotipy.Spotify(client_credentials_manager='2a369d4afd1e4eccafe667acb8f35307')

results = spotify.artist_albums(birdy_uri, album_type='album')
albums = results['items']
while results['next']:
    results = spotify.next(results)
    albums.extend(results['items'])

for album in albums:
    print(album['name'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-d6dfd87226ac> in <module>
#       5 spotify = spotipy.Spotify(client_credentials_manager='2a369d4afd1e4eccafe667acb8f35307')
#       6
# ----> 7 results = spotify.artist_albums(birdy_uri, album_type='album')
#       8 albums = results['items']
#       9 while results['next']:
#
# ~\anaconda3\lib\site-packages\spotipy\client.py in artist_albums(self, artist_id, album_type, country, limit, offset)
#     384
#     385         trid = self._get_id("artist", artist_id)
# --> 386         return self._get(
#     387             "artists/" + trid + "/albums",
#     388             album_type=album_type,
#
# ~\anaconda3\lib\site-packages\spotipy\client.py in _get(self, url, args, payload, **kwargs)
#     289             kwargs.update(args)
#     290
# --> 291         return self._internal_call("GET", url, payload, kwargs)
# ...

# %%
! git clone https://github.com/yicheng-w/CommonSenseMultiHopQA.git
# Out:
# 'git' is not recognized as an internal or external command,
# operable program or batch file.

# %%
gh repo clone twitterdev/spotatweet
# Out:
#   File "<ipython-input-5-debe3e08e52c>", line 1
#     gh repo clone twitterdev/spotatweet
#        ^
# SyntaxError: invalid syntax

# %%
curl -X "GET" "https://api.spotify.com/v1/albums/6TVfiWmo8KtflUAmkK9gGF/tracks" -H "Accept: application/json" -H "Content-Type: application/json" -H "Authorization: Bearer "
# Out:
#   File "<ipython-input-8-e0ae59a77c95>", line 1
#     curl -X "GET" "https://api.spotify.com/v1/albums/6TVfiWmo8KtflUAmkK9gGF/tracks" -H "Accept: application/json" -H "Content-Type: application/json" -H "Authorization: Bearer "
#             ^
# SyntaxError: invalid syntax

# %%
spotify:track:6rPO02ozF3bM7NnOV4h6s2
# Out:
#   File "<ipython-input-5-e3fd4e55a353>", line 1
#     spotify:track:6rPO02ozF3bM7NnOV4h6s2
#                  ^
# SyntaxError: invalid syntax

# %%
! curl
https://api.spotify.com/v1/artists/1vCWHaC5f2uS3yhpwWbIA6/albums?album_type=SINGLE&offset=20&limit=10
# Out:
#   File "<ipython-input-11-a1a95b59c516>", line 2
#     https://api.spotify.com/v1/artists/1vCWHaC5f2uS3yhpwWbIA6/albums?album_type=SINGLE&offset=20&limit=10
#           ^
# SyntaxError: invalid syntax

# %%
pip install fycharts
# Out:
# ...
#   Attempting uninstall: urllib3Note: you may need to restart the kernel to use updated packages.
# ERROR: spotipy 2.17.1 has requirement requests>=2.25.0, but you'll have requests 2.24.0 which is incompatible.
# ERROR: spotipy 2.17.1 has requirement urllib3>=1.26.0, but you'll have urllib3 1.25.11 which is incompatible.
#     Found existing installation: urllib3 1.26.4
#     Uninstalling urllib3-1.26.4:
#       Successfully uninstalled urllib3-1.26.4
#   Attempting uninstall: requests
#     Found existing installation: requests 2.25.1
#     Uninstalling requests-2.25.1:
#       Successfully uninstalled requests-2.25.1
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.0.5
#     Uninstalling pandas-1.0.5:
#       Successfully uninstalled pandas-1.0.5
# ...

# %%
from fycharts.SpotifyCharts import SpotifyCharts

api = SpotifyCharts()
api.top200Daily(output_file = "top_200_daily.csv")
# Out:
# INFO : 13/04/2021 11:06:14 PM : Extracting top 200 daily for 2017-01-01 - global
# INFO : 13/04/2021 11:06:15 PM : Extracting top 200 daily for 2017-01-01 - ad
# INFO : 13/04/2021 11:06:15 PM : Appending data to the file top_200_daily.csv...
# INFO : 13/04/2021 11:06:15 PM : Done appending to the file top_200_daily.csv!!!
# ERROR : 13/04/2021 11:06:23 PM : ***** <<HTTPSConnectionPool(host='spotifycharts.com', port=443): Max retries exceeded with url: /regional/ad/daily/2017-01-01/download (Caused by ResponseError('too many 404 error responses'))>> Data not found. Generating empty dataframe *****
# INFO : 13/04/2021 11:06:23 PM : Extracting top 200 daily for 2017-01-01 - ar
# INFO : 13/04/2021 11:06:23 PM : Appending data to the file top_200_daily.csv...
# INFO : 13/04/2021 11:06:23 PM : Done appending to the file top_200_daily.csv!!!
# INFO : 13/04/2021 11:06:24 PM : Extracting top 200 daily for 2017-01-01 - at
# ...
